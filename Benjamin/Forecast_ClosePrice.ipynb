# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
#  # Préparation des données

# %%
df = pd.read_csv("BTCBUSD_15m.csv")

# %%
df.tail(-50)
# Out:
#         Symbol Interval   TimeOpenLong  TimeCloseLong  \
# 50     BTCBUSD      15m  1610479800000   1.610481e+12
# 51     BTCBUSD      15m  1610480700000   1.610482e+12
# 52     BTCBUSD      15m  1610481600000   1.610482e+12
# 53     BTCBUSD      15m  1610481600000   1.610482e+12
# 54     BTCBUSD      15m  1610482500000   1.610483e+12
# ...        ...      ...            ...            ...
# 48106  BTCBUSD      15m  1646227800000            NaN
# 48107  BTCBUSD      15m  1646228700000            NaN
# 48108  BTCBUSD      15m  1646229600000            NaN
# 48109  BTCBUSD      15m  1646230500000            NaN
# 48110  BTCBUSD      15m  1646231400000            NaN
#
#                           DateOpen                    DateClose  OpenPrice  \
# 50     2021-01-12 19:30:00.0000000  2021-01-12 19:44:59.9990000    34516.2
# 51     2021-01-12 19:45:00.0000000  2021-01-12 19:59:59.9990000    34217.5
# 52     2021-01-12 20:00:00.0000000  2021-01-12 20:14:59.9990000    34581.7
# ...

# %%
len(df)
# Out:
# 48111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48111 entries, 0 to 48110
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Symbol                    48111 non-null  object
#  1   Interval                  48111 non-null  object
#  2   TimeOpenLong              48111 non-null  int64
#  3   TimeCloseLong             48082 non-null  float64
#  4   DateOpen                  48111 non-null  object
#  5   DateClose                 48082 non-null  object
#  6   OpenPrice                 48082 non-null  float64
#  7   ClosePrice                48082 non-null  float64
#  8   MaxPrice                  48082 non-null  float64
#  9   MinPrice                  48082 non-null  float64
#  10  Volume                    48082 non-null  float64
#  11  QuoteAssetVolume          48082 non-null  float64
#  12  NumberOfTrades            48082 non-null  float64
# ...

# %% [markdown]
#  # Modèles
